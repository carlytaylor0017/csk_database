# %%
cd /home/carlywolfbrandt/galvanize/assignments/csk_database
# Out:
# /home/carlywolfbrandt/galvanize/assignments/csk_database

# %%
import pandas as pd
import numpy as np
import string
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
import os
import requests
import json 
from tqdm import tqdm
from pandas.io.json import json_normalize

# %%
df = pd.read_csv('combined_data.gz', compression='gzip', header=0, index_col = 0, sep=',', quotechar='"')

# %%
df.count()
# Out:
# PC_Compounds_0_atoms_aid_0                    1379
# PC_Compounds_0_atoms_aid_1                    1379
# PC_Compounds_0_atoms_aid_10                   1379
# PC_Compounds_0_atoms_aid_100                     2
# PC_Compounds_0_atoms_aid_101                     2
# PC_Compounds_0_atoms_aid_102                     2
# PC_Compounds_0_atoms_aid_11                   1379
# PC_Compounds_0_atoms_aid_12                   1376
# PC_Compounds_0_atoms_aid_13                   1375
# PC_Compounds_0_atoms_aid_14                   1374
# PC_Compounds_0_atoms_aid_15                   1372
# PC_Compounds_0_atoms_aid_16                   1367
# PC_Compounds_0_atoms_aid_17                   1366
# PC_Compounds_0_atoms_aid_18                   1354
# PC_Compounds_0_atoms_aid_19                   1343
# PC_Compounds_0_atoms_aid_2                    1379
# PC_Compounds_0_atoms_aid_20                   1316
# PC_Compounds_0_atoms_aid_21                   1297
# PC_Compounds_0_atoms_aid_22                   1255
# PC_Compounds_0_atoms_aid_23                   1221
# PC_Compounds_0_atoms_aid_24                   1173
# PC_Compounds_0_atoms_aid_25                   1116
# PC_Compounds_0_atoms_aid_26                   1051
# PC_Compounds_0_atoms_aid_27                   1008
# PC_Compounds_0_atoms_aid_28                    917
# PC_Compounds_0_atoms_aid_29                    864
# PC_Compounds_0_atoms_aid_3                    1379
# PC_Compounds_0_atoms_aid_30                    809
# PC_Compounds_0_atoms_aid_31                    740
# PC_Compounds_0_atoms_aid_32                    681
#                                               ...
# PC_Compounds_0_stereo_6_tetrahedral_parity       6
# PC_Compounds_0_stereo_6_tetrahedral_top          6
# PC_Compounds_0_stereo_6_tetrahedral_type         6
# PC_Compounds_0_stereo_7_tetrahedral_above        6
# PC_Compounds_0_stereo_7_tetrahedral_below        6
# PC_Compounds_0_stereo_7_tetrahedral_bottom       6
# PC_Compounds_0_stereo_7_tetrahedral_center       6
# PC_Compounds_0_stereo_7_tetrahedral_parity       6
# PC_Compounds_0_stereo_7_tetrahedral_top          6
# PC_Compounds_0_stereo_7_tetrahedral_type         6
# PC_Compounds_0_stereo_8_planar_lbottom           1
# PC_Compounds_0_stereo_8_planar_left              1
# PC_Compounds_0_stereo_8_planar_ltop              1
# PC_Compounds_0_stereo_8_planar_parity            1
# PC_Compounds_0_stereo_8_planar_rbottom           1
# PC_Compounds_0_stereo_8_planar_right             1
# PC_Compounds_0_stereo_8_planar_rtop              1
# PC_Compounds_0_stereo_8_planar_type              1
# PC_Compounds_0_stereo_8_tetrahedral_above        1
# PC_Compounds_0_stereo_8_tetrahedral_below        1
# PC_Compounds_0_stereo_8_tetrahedral_bottom       1
# PC_Compounds_0_stereo_8_tetrahedral_center       1
# PC_Compounds_0_stereo_8_tetrahedral_parity       1
# PC_Compounds_0_stereo_8_tetrahedral_top          1
# PC_Compounds_0_stereo_8_tetrahedral_type         1
# image_url                                     2100
# isosmiles                                     2100
# json_url                                      2100
# parent_id                                     2100
# version_id                                    2100
# Length: 1342, dtype: int64

# %%
df.head()
# Out:
#    PC_Compounds_0_atoms_aid_0  PC_Compounds_0_atoms_aid_1  \
# 0                         1.0                         2.0
# 0                         1.0                         2.0
# 0                         1.0                         2.0
# 0                         1.0                         2.0
# 0                         1.0                         2.0
#
#    PC_Compounds_0_atoms_aid_10  PC_Compounds_0_atoms_aid_100  \
# 0                         11.0                           NaN
# 0                         11.0                           NaN
# 0                         11.0                           NaN
# 0                         11.0                           NaN
# 0                         11.0                           NaN
#
#    PC_Compounds_0_atoms_aid_101  PC_Compounds_0_atoms_aid_102  \
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
#
#    PC_Compounds_0_atoms_aid_11  PC_Compounds_0_atoms_aid_12  \
# 0                         12.0                          NaN
# 0                         12.0                         13.0
# 0                         12.0                         13.0
# 0                         12.0                         13.0
# 0                         12.0                         13.0
#
#    PC_Compounds_0_atoms_aid_13  PC_Compounds_0_atoms_aid_14  ...  \
# 0                          NaN                          NaN  ...
# 0                         14.0                         15.0  ...
# 0                         14.0                         15.0  ...
# 0                          NaN                          NaN  ...
# 0                         14.0                         15.0  ...
#
#    PC_Compounds_0_stereo_8_tetrahedral_bottom  \
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
#
#    PC_Compounds_0_stereo_8_tetrahedral_center  \
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
#
#    PC_Compounds_0_stereo_8_tetrahedral_parity  \
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
#
#    PC_Compounds_0_stereo_8_tetrahedral_top  \
# 0                                      NaN
# 0                                      NaN
# 0                                      NaN
# 0                                      NaN
# 0                                      NaN
#
#    PC_Compounds_0_stereo_8_tetrahedral_type  \
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
#
#                                            image_url    isosmiles  \
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...     c1ccccc1
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...   Cc1ccccc1C
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...   CCc1ccccc1
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...  C1c2ccccc12
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...  CCc1ccccc1C
#
#                                             json_url  parent_id  version_id
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...     479848      479848
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...  299961464   299961464
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...     475202      475202
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...  301251831   301251831
# 0  https://pubchem.ncbi.nlm.nih.gov/rest/pug/comp...     475997      475997
#
# [5 rows x 1342 columns]

# %%
len(df.columns)
# Out:
# 1342
